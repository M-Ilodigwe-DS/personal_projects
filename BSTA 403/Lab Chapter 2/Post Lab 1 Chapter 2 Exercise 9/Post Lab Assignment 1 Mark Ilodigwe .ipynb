# %% [markdown]
# # Mark Ilodigwe Post Lab Assignment 1

# %% [markdown]
# ## 1. Which of the predictors are quantitative, and which are quali- tative?
# - Quantitiatve Predictors
#  - MPG
#  - Cylinders
#  - Displacement
#  - Horsepower
#  - Weight
#  - Acceleration
#
#
# - Qualatitave Predictors
#  - Name (non-numerical data)
#  - Origin (factor with 3 levels)
#  - Year

# %%
import pandas as pd
import numpy as np

# %%
data=pd.read_csv("Auto.csv")
data.head(50)
data1=data['horsepower'].replace('?', 0)
del data['horsepower']

# %%
data.insert(3,'horsepower',data1)
data['horsepower'] = pd.to_numeric(data['horsepower'])
data
# Out:
#       mpg  cylinders  displacement  horsepower  weight  acceleration  year  \
# 0    18.0          8         307.0         130    3504          12.0    70
# 1    15.0          8         350.0         165    3693          11.5    70
# 2    18.0          8         318.0         150    3436          11.0    70
# 3    16.0          8         304.0         150    3433          12.0    70
# 4    17.0          8         302.0         140    3449          10.5    70
# ..    ...        ...           ...         ...     ...           ...   ...
# 392  27.0          4         140.0          86    2790          15.6    82
# 393  44.0          4          97.0          52    2130          24.6    82
# 394  32.0          4         135.0          84    2295          11.6    82
# 395  28.0          4         120.0          79    2625          18.6    82
# 396  31.0          4         119.0          82    2720          19.4    82
#
#      origin                       name
# ...

# %%
data['horsepower'] = pd.to_numeric(data['horsepower'])
data
# Out:
#       mpg  cylinders  displacement  horsepower  weight  acceleration  year  \
# 0    18.0          8         307.0         130    3504          12.0    70
# 1    15.0          8         350.0         165    3693          11.5    70
# 2    18.0          8         318.0         150    3436          11.0    70
# 3    16.0          8         304.0         150    3433          12.0    70
# 4    17.0          8         302.0         140    3449          10.5    70
# ..    ...        ...           ...         ...     ...           ...   ...
# 392  27.0          4         140.0          86    2790          15.6    82
# 393  44.0          4          97.0          52    2130          24.6    82
# 394  32.0          4         135.0          84    2295          11.6    82
# 395  28.0          4         120.0          79    2625          18.6    82
# 396  31.0          4         119.0          82    2720          19.4    82
#
#      origin                       name
# ...

# %%
data.value_counts()
# Out:
# mpg   cylinders  displacement  horsepower  weight  acceleration  year  origin  name
# 9.0   8          304.0         193         4732    18.5          70    1       hi 1200d                                1
# 27.2  4          119.0         97          2300    14.7          78    3       datsun 510                              1
# 27.0  4          151.0         90          2735    18.0          82    1       pontiac phoenix                         1
#                  140.0         86          2790    15.6          82    1       ford mustang gl                         1
#                  112.0         88          2640    18.6          82    1       chevrolet cavalier wagon                1
#                                                                                                                       ..
# 18.6  6          225.0         110         3620    18.7          78    1       dodge aspen                             1
# ...

# %% [markdown]
# ## 2. What is the range of each quantitative predictor? You can an- swer this using the min() and max() methods in numpy.
#
# ## 3.  What is the mean and standard deviation of each quantitative predictor?

# %%
print("The max for MPG:", max(data['mpg']))
print("The min for MPG:", min(data['mpg']))
print('The mean for MPG:', np.mean(data['mpg']))
print('The standard deviation for MPG:', np.std(data['mpg']))
# Out:
# The max for MPG: 46.6
# The min for MPG: 9.0
# The mean for MPG: 23.515869017632248
# The standard deviation for MPG: 7.815941538224255

# %%
print("The max for cylinders :", max(data['cylinders']))
print("The min for cylinders:", min(data['cylinders']))
print('The mean for cylinders:', np.mean(data['cylinders']))
print('The standard deviation for cylinders', np.std(data['cylinders']))
# Out:
# The max for cylinders : 8
# The min for cylinders: 3
# The mean for cylinders: 5.458438287153652
# The standard deviation for cylinders 1.699432585509141

# %%
print("The max for horsepower:", max(data['horsepower']))
print("The min for horsepower:", min(data['horsepower']))
print('The mean for horsepower:', np.mean(data['horsepower']))
print('The standard deviation for horsepower:', np.std(data['horsepower']))
# Out:
# The max for horsepower: 230
# The min for horsepower: 0
# The mean for horsepower: 103.15365239294711
# The standard deviation for horsepower: 39.9362094369447

# %%
print("The max for displacement:", max(data['displacement']))
print("The min for displacement:", min(data['displacement'])) 
print('The mean for displacement:', np.mean(data['displacement']))
print('The standard deviation for displacement:', np.std(data['displacement']))
# Out:
# The max for displacement: 455.0
# The min for displacement: 68.0
# The mean for displacement: 193.53274559193954
# The standard deviation for displacement: 104.24803997948825

# %%
print("The max for weight:", max(data['weight']))
print("The min for weight:", min(data['weight']))
print('The mean for weight:', np.mean(data['weight']))
print('The standard deviation for weight', np.std(data['weight']))
# Out:
# The max for weight: 5140
# The min for weight: 1613
# The mean for weight: 2970.2619647355164
# The standard deviation for weight 846.8355568478047

# %%
print("The max for acceleration:", max(data['acceleration']))
print("The min for acceleration:", min(data['acceleration']))
print('The mean for acceleration:', np.mean(data['acceleration']))
print('The standard deviation for acceleration:', np.std(data['acceleration']))
# Out:
# The max for acceleration: 24.8
# The min for acceleration: 8.0
# The mean for acceleration: 15.555667506297214
# The standard deviation for acceleration: 2.746529639056109

# %%
# Out:
# The max for: year 82
# The min for year: 70
# The mean for year: 75.99496221662469
# The standard deviation for year: 3.6853546098832153

# %%
data2=data.copy()

# %%
data2=data2.drop(data2.index[9:85])

data2
# Out:
#       mpg  cylinders  displacement  horsepower  weight  acceleration  year  \
# 0    18.0          8         307.0         130    3504          12.0    70
# 1    15.0          8         350.0         165    3693          11.5    70
# 2    18.0          8         318.0         150    3436          11.0    70
# 3    16.0          8         304.0         150    3433          12.0    70
# 4    17.0          8         302.0         140    3449          10.5    70
# ..    ...        ...           ...         ...     ...           ...   ...
# 392  27.0          4         140.0          86    2790          15.6    82
# 393  44.0          4          97.0          52    2130          24.6    82
# 394  32.0          4         135.0          84    2295          11.6    82
# 395  28.0          4         120.0          79    2625          18.6    82
# 396  31.0          4         119.0          82    2720          19.4    82
#
#      origin                       name
# ...

# %%
print("The dropped max for MPG:", max(data2['mpg']))
print("The dropped min for MPG:", min(data2['mpg']))
print('The dropped mean for MPG:', np.mean(data2['mpg']))
print('The dropped standard deviation for MPG:', np.std(data2['mpg']))
# Out:
# The dropped max for MPG: 46.6
# The dropped min for MPG: 11.0
# The dropped mean for MPG: 24.438629283489092
# The dropped standard deviation for MPG: 7.8958565964792164

# %%
print("The dropped max for cylinders :", max(data2['cylinders']))
print("The dropped min for cylinders:", min(data2['cylinders']))
print('The dropped mean for cylinders:', np.mean(data2['cylinders']))
print('The dropped standard deviation for cylinders', np.std(data2['cylinders']))
# Out:
# The dropped max for cylinders : 8
# The dropped min for cylinders: 3
# The dropped mean for cylinders: 5.370716510903427
# The dropped standard deviation for cylinders 1.650908119022154

# %%
print("The dropped max for horsepower:", max(data2['horsepower']))
print("The dropped min for horsepower:", min(data2['horsepower']))
print('The dropped mean for horsepower:', np.mean(data2['horsepower']))
print('The dropped standard deviation for horsepower:', np.std(data2['horsepower']))
# Out:
# The dropped max for horsepower: 230
# The dropped min for horsepower: 0
# The dropped mean for horsepower: 99.69781931464175
# The dropped standard deviation for horsepower: 37.33421040108724

# %%
print("The dropped max for displacement:", max(data2['displacement']))
print("The dropped min for displacement:", min(data2['displacement'])) 
print('The dropped mean for displacement:', np.mean(data2['displacement']))
print('The dropped standard deviation for displacement:', np.std(data2['displacement']))
# Out:
# The dropped max for displacement: 455.0
# The dropped min for displacement: 68.0
# The dropped mean for displacement: 187.04984423676012
# The dropped standard deviation for displacement: 99.48006895812567

# %%
print("The dropped max for weight:", max(data2['weight']))
print("The dropped min for weight:", min(data2['weight']))
print('The dropped  mean for weight:', np.mean(data2['weight']))
print('The dropped standard deviation for weight', np.std(data2['weight']))
# Out:
# The dropped max for weight: 4997
# The dropped min for weight: 1649
# The dropped  mean for weight: 2933.96261682243
# The dropped standard deviation for weight 809.3792697745696

# %%
print("The dropped max for acceleration:", max(data2['acceleration']))
print("The dropped  min for acceleration:", min(data2['acceleration']))
print('The dropped mean for acceleration:', np.mean(data2['acceleration']))
print('The dropped standard deviation for accelertion:', np.std(data2['acceleration']))
# Out:
# The dropped max for acceleration: 24.8
# The dropped  min for acceleration: 8.5
# The dropped mean for acceleration: 15.723052959501556
# The dropped standard deviation for accelertion: 2.6763353193767756

# %%
# Out:
# The dropped max for: year 82
# The dropped min for year: 70
# The dropped mean for year: 78.25714285714285
# The dropped standard deviation for year: 2.7096200501779806

# %% [markdown]
# ## 4. Using the full data set, investigate the predictors graphically, using scatterplots or other tools of your choice. Create some plots highlighting the relationship

# %%
from matplotlib.pyplot import subplots
import matplotlib.pyplot as plt
data.dtypes
# Out:
# mpg             float64
# cylinders         int64
# displacement    float64
# horsepower        int64
# weight            int64
# acceleration    float64
# year              int64
# origin            int64
# name             object
# dtype: object

# %%
data['mpg'].astype(float)
data['cylinders'].astype(float)
data['horsepower'].astype(float)
data['displacement'].astype(float)
data['weight'].astype(float)
data['acceleration'].astype(float)
data['year'].astype("category")
data['origin'].astype('category')
data['name'].astype("category")
# Out:
# 0      chevrolet chevelle malibu
# 1              buick skylark 320
# 2             plymouth satellite
# 3                  amc rebel sst
# 4                    ford torino
#                  ...
# 392              ford mustang gl
# 393                    vw pickup
# 394                dodge rampage
# 395                  ford ranger
# 396                   chevy s-10
# Name: name, Length: 397, dtype: category
# Categories (304, object): ['amc ambassador brougham', 'amc ambassador dpl', 'amc ambassador sst', 'amc concord', ..., 'vw pickup', 'vw rabbit', 'vw rabbit c (diesel)', 'vw rabbit custom']

# %%
m=data['mpg']
c=data['cylinders']
h=data['horsepower']
d=data['displacement']
w=data['weight']
a=data['acceleration']
y=data['year']
o=data['origin']
n=data['name']

# %%
fig, axes = subplots(nrows=2,ncols=3,figsize=(15, 5))

#Plots for mpg
axes[0,0].scatter(m, c, s=20)

axes[0,1].scatter(m, h, s=20)

axes[1,0].scatter(m, d, s=20)
axes[1,1].scatter(m, w, s=20)
axes[1,2].scatter(m, a, s=20)

# %%
fig, axes = subplots(nrows=2,ncols=3,figsize=(15, 5))
#Plots for cylinder

axes[0,0].scatter(c,m, s=20)
axes[0,1].scatter(c, h, s=20)

axes[1,0].scatter(c, d, s=20)
axes[1,1].scatter(c, w, s=20)
axes[1,2].scatter(c, a, s=20)

# %%
fig, axes = subplots(nrows=2,ncols=3,figsize=(15, 5))
#Plots for horsepower 

axes[0,0].scatter(h,m, s=10)
axes[0,1].scatter(h, c, s=10)

axes[1,0].scatter(h, d, s=10)
axes[1,1].scatter(h, w, s=10)
axes[1,2].scatter(h, a, s=10)

# %%
fig, axes = subplots(nrows=2,ncols=3,figsize=(15, 5))
#Plots for weight

axes[0,0].scatter(w,m, s=10)
axes[0,1].plot(w, c, 'o')
axes[0,2].scatter(w, h, s=10)
axes[1,0].scatter(w, d, s=10)

axes[1,2].scatter(w, a, s=10)

# %%
fig, axes = subplots(nrows=2,ncols=3,figsize=(15, 5))
#Plots for accerlation
axes[0,0].scatter(a,m, s=10)
axes[0,1].plot(a, c, 'o')
axes[0,2].scatter(a, h, s=10)
axes[1,0].scatter(a, d, s=10)
axes[1,1].scatter(a, w, s=10)

# %%
fig, axes = subplots(nrows=2,ncols=3,figsize=(15, 5))

axes[0,0].scatter(d,m, s=10)
axes[0,1].plot(d, c, 'o')
axes[0,2].plot(d, h, 'o')

axes[1,1].plot(d, w, 'o')
axes[1,2].plot(d, a, 'o')

# %% [markdown]
#  ## 5. Suppose that we wish to predict gas mileage (mpg) on the basis of the other variables. Do your plots suggest that any of the other variables might be useful in predicting mpg? Justify your answer.
#
#  Based on the gaph, I believe that horsepower, displacement, weight, and cylinders would have the greatest use when predicting mpg. All such variables have a somewhat strong negative correlation or R^2 value which clusters around the range (-.8) - (-.75) for these variables.
#
#
#  It can be noted as there is a increase in one of these variables, miles per gallon also decreased which would mean the car is less gas efficient. This negative association can be seean within each of the plotted graphs.

# %%
fig, axes = subplots(nrows=2,ncols=3,figsize=(15, 5))

#Plots for mpg
axes[0,0].scatter(m, c, s=20)

axes[0,1].scatter(m, h, s=20)

 
axes[1,0].scatter(m, d, s=20)
axes[1,1].scatter(m, w, s=20)
axes[1,2].scatter(m, a, s=20)


data.corr()
# Out:
#                    mpg  cylinders  displacement  horsepower    weight  \
# mpg           1.000000  -0.776260     -0.804443   -0.761004 -0.831739
# cylinders    -0.776260   1.000000      0.950920    0.823711  0.897017
# displacement -0.804443   0.950920      1.000000    0.876741  0.933104
# horsepower   -0.761004   0.823711      0.876741    1.000000  0.845483
# weight       -0.831739   0.897017      0.933104    0.845483  1.000000
# acceleration  0.422297  -0.504061     -0.544162   -0.670643 -0.419502
# year          0.581469  -0.346717     -0.369804   -0.405830 -0.307900
# origin        0.563698  -0.564972     -0.610664   -0.427052 -0.581265
#
#               acceleration      year    origin
# mpg               0.422297  0.581469  0.563698
# cylinders        -0.504061 -0.346717 -0.564972
# displacement     -0.544162 -0.369804 -0.610664
# horsepower       -0.670643 -0.405830 -0.427052
# weight           -0.419502 -0.307900 -0.581265
# acceleration      1.000000  0.282901  0.210084
# ...
